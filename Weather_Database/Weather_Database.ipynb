# %%
# Add dependencies
import pandas as pd
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90, high=90, size=2000)
lons = np.random.uniform(low=-180, high=180, size=2000)

lats_lons = zip(lats, lons)
lats_lons

# %%
# Add the lats and lons to a list 
coordinates = list(lats_lons)

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Perform an API call with the OpenWeatherMap.
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval")

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")

    # Log the record for the city.
    print(f"Processing Record for {city}")

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# Processing Record for longyearbyen
# Processing Record for khatanga
# Processing Record for punta arenas
# Processing Record for tiksi
# Processing Record for severo-kurilsk
# Processing Record for itaguai
# Processing Record for kabo
# Processing Record for lompoc
# Processing Record for new norfolk
# Processing Record for clyde river
# Processing Record for mataura
# Processing Record for rikitea
# Processing Record for iqaluit
# Processing Record for ancud
# Processing Record for illoqqortoormiut
# City not found. Skipping...
# Processing Record for tiarei
# Processing Record for ushuaia
# Processing Record for tasiilaq
# Processing Record for esmeraldas
# Processing Record for georgetown
# Processing Record for ipu
# Processing Record for haapiti
# Processing Record for rawson
# Processing Record for kununurra
# Processing Record for butaritari
# Processing Record for lujan
# Processing Record for la ronge
# Processing Record for tuktoyaktuk
# Processing Record for haines junction
# Processing Record for vuktyl
# Processing Record for busselton
# Processing Record for hithadhoo
# Processing Record for kapaa
# Processing Record for pevek
# Processing Record for saint-augustin
# Processing Record for semey
# Processing Record for cherskiy
# Processing Record for albany
# Processing Record for bayanday
# Processing Record for jamestown
# Processing Record for avarua
# Processing Record for puerto ayora
# Processing Record for pedernales
# Processing Record for cape town
# Processing Record for huarmey
# Processing Record for bereda
# Processing Record for codrington
# Processing Record for provideniya
# Processing Record for saint-philippe
# Processing Record for beringovskiy
# Processing Record for hobart
# Processing Record for minab
# Processing Record for gorontalo
# Processing Record for mehamn
# Processing Record for souillac
# Processing Record for hamilton
# Processing Record for orodara
# Processing Record for port alfred
# Processing Record for henties bay
# Processing Record for buriti bravo
# Processing Record for porto walter
# Processing Record for krutinka
# Processing Record for hermanus
# Processing Record for vaini
# Processing Record for ossora
# Processing Record for mount isa
# Processing Record for getulio vargas
# Processing Record for saldanha
# Processing Record for necochea
# Processing Record for mar del plata
# Processing Record for meulaboh
# Processing Record for taolanaro
# City not found. Skipping...
# Processing Record for barentsburg
# City not found. Skipping...
# Processing Record for kiruna
# Processing Record for hilo
# Processing Record for atuona
# Processing Record for tabiauea
# City not found. Skipping...
# Processing Record for buenos aires
# Processing Record for camacha
# Processing Record for nemuro
# Processing Record for birjand
# Processing Record for ilulissat
# Processing Record for airai
# Processing Record for ribeira grande
# Processing Record for norman wells
# Processing Record for chokurdakh
# Processing Record for nakamura
# Processing Record for noyabrsk
# Processing Record for nikolskoye
# Processing Record for ibra
# Processing Record for bethel
# Processing Record for laguna de duero
# Processing Record for nagorsk
# Processing Record for lhokseumawe
# Processing Record for ravar
# Processing Record for lebu
# Processing Record for pacific grove
# Processing Record for victoria
# Processing Record for temaraia
# City not found. Skipping...
# Processing Record for cradock
# Processing Record for dipolog
# Processing Record for kousseri
# Processing Record for east london
# Processing Record for abashiri
# Processing Record for banjar
# Processing Record for kruisfontein
# Processing Record for makakilo city
# Processing Record for carnarvon
# Processing Record for mahebourg
# Processing Record for belushya guba
# City not found. Skipping...
# Processing Record for zhezkazgan
# Processing Record for avera
# Processing Record for cabo san lucas
# Processing Record for rudnya
# Processing Record for barraute
# Processing Record for kamenskoye
# City not found. Skipping...
# Processing Record for butterworth
# Processing Record for morondava
# Processing Record for samusu
# City not found. Skipping...
# Processing Record for porto novo
# Processing Record for peniche
# Processing Record for aklavik
# Processing Record for qaanaaq
# Processing Record for pozo colorado
# Processing Record for bredasdorp
# Processing Record for bonn
# Processing Record for tansen
# Processing Record for bogandinskiy
# Processing Record for moron
# Processing Record for ponta do sol
# Processing Record for port hardy
# Processing Record for esperance
# Processing Record for flin flon
# Processing Record for kodiak
# Processing Record for paita
# Processing Record for marfino
# Processing Record for dikson
# Processing Record for tasbuget
# City not found. Skipping...
# Processing Record for hasaki
# Processing Record for upernavik
# Processing Record for yerbogachen
# Processing Record for yellowknife
# Processing Record for lasa
# Processing Record for hovd
# Processing Record for san miguel
# Processing Record for muros
# Processing Record for bluff
# Processing Record for margate
# Processing Record for bosaso
# Processing Record for nam tha
# City not found. Skipping...
# Processing Record for hambantota
# Processing Record for komsomolskiy
# Processing Record for suntar
# Processing Record for satitoa
# City not found. Skipping...
# Processing Record for chuy
# Processing Record for arraial do cabo
# Processing Record for nizhneyansk
# City not found. Skipping...
# Processing Record for ixtapa
# Processing Record for leningradskiy
# Processing Record for barrow
# Processing Record for constitucion
# Processing Record for nanortalik
# Processing Record for vaitupu
# City not found. Skipping...
# Processing Record for alofi
# Processing Record for kulunda
# Processing Record for shingu
# Processing Record for cidreira
# Processing Record for klaksvik
# Processing Record for bambous virieux
# Processing Record for jiddah
# City not found. Skipping...
# Processing Record for saleaula
# City not found. Skipping...
# Processing Record for xingyi
# Processing Record for sao filipe
# Processing Record for inirida
# Processing Record for kavaratti
# Processing Record for pindushi
# Processing Record for sitapur
# Processing Record for attawapiskat
# City not found. Skipping...
# Processing Record for mandalgovi
# Processing Record for kutum
# Processing Record for taikang
# Processing Record for iskateley
# Processing Record for vao
# Processing Record for tianpeng
# Processing Record for ambanja
# Processing Record for kamenka
# Processing Record for pisco
# Processing Record for jeremie
# Processing Record for alotau
# City not found. Skipping...
# Processing Record for rio gallegos
# Processing Record for flagstaff
# Processing Record for immokalee
# Processing Record for kasangulu
# Processing Record for veraval
# Processing Record for mount gambier
# Processing Record for ridgecrest
# Processing Record for tiznit
# Processing Record for san jeronimo
# Processing Record for salamanca
# Processing Record for acari
# Processing Record for marcona
# City not found. Skipping...
# Processing Record for puerto quijarro
# Processing Record for tura
# Processing Record for thompson
# Processing Record for vila velha
# Processing Record for castro
# Processing Record for quatre cocos
# Processing Record for amderma
# City not found. Skipping...
# Processing Record for asyut
# Processing Record for perth
# Processing Record for luderitz
# Processing Record for sakakah
# Processing Record for kirakira
# Processing Record for mys shmidta
# City not found. Skipping...
# Processing Record for hervey bay
# Processing Record for do rud
# City not found. Skipping...
# Processing Record for husavik
# Processing Record for novikovo
# Processing Record for crab hill
# City not found. Skipping...
# Processing Record for grand river south east
# City not found. Skipping...
# Processing Record for cururupu
# Processing Record for baker city
# Processing Record for asau
# Processing Record for qobu
# Processing Record for atherton
# Processing Record for saint-pierre
# Processing Record for yeppoon
# Processing Record for wanxian
# Processing Record for ust-nera
# Processing Record for hami
# Processing Record for geraldton
# Processing Record for visnes
# Processing Record for morehead
# Processing Record for ostrovnoy
# Processing Record for cabot
# Processing Record for dunedin
# Processing Record for linfen
# Processing Record for imbituba
# Processing Record for antofagasta
# Processing Record for boda
# Processing Record for hihifo
# City not found. Skipping...
# Processing Record for markova
# Processing Record for buala
# Processing Record for monastyrshchina
# Processing Record for tambura
# Processing Record for sitka
# Processing Record for san juan
# Processing Record for jawhar
# Processing Record for phuntsholing
# Processing Record for guerrero negro
# Processing Record for anchorage
# Processing Record for alihe
# Processing Record for shemonaikha
# Processing Record for college
# Processing Record for am timan
# Processing Record for cerqueira cesar
# Processing Record for mataram
# Processing Record for grande prairie
# Processing Record for fort saint john
# City not found. Skipping...
# Processing Record for tabialan
# City not found. Skipping...
# Processing Record for bargal
# City not found. Skipping...
# Processing Record for awbari
# Processing Record for joao pinheiro
# Processing Record for solhan
# Processing Record for matiguas
# Processing Record for juneau
# Processing Record for gurgentepe
# Processing Record for shelbyville
# Processing Record for ormara
# Processing Record for cobija
# Processing Record for port lincoln
# Processing Record for wahiawa
# Processing Record for namibe
# Processing Record for palu
# Processing Record for kaitangata
# Processing Record for ningbo
# Processing Record for kavieng
# Processing Record for tadine
# Processing Record for atambua
# Processing Record for belyy yar
# Processing Record for pangnirtung
# Processing Record for torbay
# Processing Record for port elizabeth
# Processing Record for tezu
# Processing Record for vila
# Processing Record for quebrada de yoro
# City not found. Skipping...
# Processing Record for bur gabo
# City not found. Skipping...
# Processing Record for noumea
# Processing Record for namatanai
# Processing Record for oeiras do para
# Processing Record for sentyabrskiy
# City not found. Skipping...
# Processing Record for svetlogorsk
# Processing Record for pombia
# Processing Record for meadow lake
# Processing Record for atar
# Processing Record for isangel
# Processing Record for parchim
# Processing Record for kloulklubed
# Processing Record for doha
# Processing Record for umm lajj
# Processing Record for tamala
# Processing Record for gornyy
# Processing Record for carutapera
# Processing Record for tazovskiy
# Processing Record for ahipara
# Processing Record for varhaug
# Processing Record for paris
# Processing Record for fare
# Processing Record for aras
# Processing Record for saskylakh
# Processing Record for talaya
# Processing Record for beloha
# Processing Record for laguna
# Processing Record for salinopolis
# Processing Record for mahendranagar
# Processing Record for mezhdurechenskiy
# Processing Record for twentynine palms
# Processing Record for vila franca do campo
# Processing Record for yarmouth
# Processing Record for yar-sale
# Processing Record for neiafu
# Processing Record for zhigansk
# Processing Record for ban nahin
# Processing Record for sobolevo
# Processing Record for waddan
# Processing Record for byron bay
# Processing Record for matara
# Processing Record for okhotsk
# Processing Record for tilichiki
# Processing Record for pokhara
# Processing Record for tsihombe
# City not found. Skipping...
# Processing Record for ballina
# Processing Record for kendari
# Processing Record for konya
# Processing Record for roma
# Processing Record for faanui
# Processing Record for san cristobal
# Processing Record for hanyang
# Processing Record for sorvag
# City not found. Skipping...
# Processing Record for melfi
# Processing Record for sorland
# Processing Record for tuatapere
# Processing Record for artyk
# City not found. Skipping...
# Processing Record for coihaique
# Processing Record for wagar
# Processing Record for portland
# Processing Record for itarema
# Processing Record for alice springs
# Processing Record for yulara
# Processing Record for lorengau
# Processing Record for mitu
# Processing Record for shahrud
# Processing Record for lavrentiya
# Processing Record for fort nelson
# Processing Record for saint-alexandre
# Processing Record for berlevag
# Processing Record for kieta
# Processing Record for stoyba
# City not found. Skipping...
# Processing Record for chaykovskaya
# Processing Record for severodvinsk
# Processing Record for touros
# Processing Record for samarai
# Processing Record for naduvattam
# Processing Record for marawi
# Processing Record for bang saphan
# Processing Record for gurgan
# City not found. Skipping...
# Processing Record for bad hofgastein
# Processing Record for onojo
# Processing Record for along
# Processing Record for banda aceh
# Processing Record for rajgarh
# Processing Record for dayong
# Processing Record for bolungarvik
# City not found. Skipping...
# Processing Record for ketchikan
# Processing Record for san patricio
# Processing Record for clarence town
# Processing Record for lazaro cardenas
# Processing Record for krasnokamensk
# Processing Record for alta floresta
# Processing Record for tacuarembo
# Processing Record for sungaipenuh
# Processing Record for kawana waters
# City not found. Skipping...
# Processing Record for doka
# Processing Record for santa maria
# Processing Record for dipkarpaz
# City not found. Skipping...
# Processing Record for bubaque
# Processing Record for anshun
# Processing Record for nishihara
# Processing Record for beira
# Processing Record for san pedro
# Processing Record for aykhal
# Processing Record for petukhovo
# Processing Record for lolua
# City not found. Skipping...
# Processing Record for padang
# Processing Record for dingle
# Processing Record for katsuura
# Processing Record for eydhafushi
# Processing Record for grand centre
# City not found. Skipping...
# Processing Record for fredericksburg
# Processing Record for soltau
# Processing Record for petropavlovsk-kamchatskiy
# Processing Record for ilo
# Processing Record for burns lake
# Processing Record for cortez
# Processing Record for stokmarknes
# Processing Record for los llanos de aridane
# Processing Record for ovalle
# Processing Record for riyadh
# Processing Record for alim
# Processing Record for priiskovyy
# Processing Record for bilibino
# Processing Record for paranaiba
# Processing Record for kyabe
# Processing Record for teneguiban
# City not found. Skipping...
# Processing Record for sao cristovao
# Processing Record for kegayli
# City not found. Skipping...
# Processing Record for sidi ali
# Processing Record for taoudenni
# Processing Record for oda
# Processing Record for mihaileni
# Processing Record for shepsi
# Processing Record for elliot
# Processing Record for lata
# Processing Record for lae
# Processing Record for marsh harbour
# Processing Record for maumere
# Processing Record for te anau
# Processing Record for honiara
# Processing Record for dori
# Processing Record for khandyga
# Processing Record for mendi
# Processing Record for baturaja
# Processing Record for vestmannaeyjar
# Processing Record for jalingo
# Processing Record for coahuayana
# Processing Record for sao felix do xingu
# Processing Record for comodoro rivadavia
# Processing Record for port moresby
# Processing Record for jefferson city
# Processing Record for santa cruz de la palma
# Processing Record for hobyo
# Processing Record for grindavik
# Processing Record for jasdan
# Processing Record for yurla
# Processing Record for umzimvubu
# City not found. Skipping...
# Processing Record for matadi
# Processing Record for yatou
# Processing Record for caxito
# Processing Record for kahului
# Processing Record for bilma
# Processing Record for valparaiso
# Processing Record for dangriga
# Processing Record for neuquen
# Processing Record for auburn
# Processing Record for palaia fokaia
# Processing Record for fortuna
# Processing Record for nehe
# Processing Record for tuyen quang
# Processing Record for areia branca
# Processing Record for talnakh
# Processing Record for turayf
# Processing Record for gat
# Processing Record for bajil
# Processing Record for pedro ii
# Processing Record for niksic
# Processing Record for adalsbruk
# City not found. Skipping...
# Processing Record for goderich
# Processing Record for kedougou
# Processing Record for kushiro
# Processing Record for tarudant
# City not found. Skipping...
# Processing Record for batagay
# Processing Record for puerto carreno
# Processing Record for lubao
# Processing Record for gubkinskiy
# Processing Record for wanaka
# Processing Record for berbera
# Processing Record for stornoway
# Processing Record for tigil
# Processing Record for bonoua
# Processing Record for saint-denis
# Processing Record for omsukchan
# Processing Record for hesla
# Processing Record for nome
# Processing Record for sarh
# Processing Record for beroroha
# Processing Record for moussoro
# Processing Record for inderborskiy
# City not found. Skipping...
# Processing Record for gigmoto
# Processing Record for sikasso
# Processing Record for yinchuan
# Processing Record for balkhash
# Processing Record for vilhena
# Processing Record for port hedland
# Processing Record for las vegas
# Processing Record for oussouye
# Processing Record for mayumba
# Processing Record for san quintin
# Processing Record for turochak
# Processing Record for paamiut
# Processing Record for christchurch
# Processing Record for nizhnyaya tavda
# Processing Record for agadez
# Processing Record for scarborough
# Processing Record for sahrak
# City not found. Skipping...
# Processing Record for may pen
# Processing Record for solnechnyy
# Processing Record for soe
# Processing Record for batagay-alyta
# Processing Record for tokur
# Processing Record for tautira
# Processing Record for kabala
# Processing Record for ninghai
# Processing Record for bom jesus
# Processing Record for ha giang
# Processing Record for moose factory
# Processing Record for poya
# Processing Record for teguise
# Processing Record for buraydah
# Processing Record for tome
# Processing Record for hillsborough
# Processing Record for otjimbingwe
# Processing Record for estancia
# Processing Record for saint george
# Processing Record for kasongo-lunda
# Processing Record for egvekinot
# Processing Record for fort smith
# Processing Record for ayagoz
# Processing Record for inhambane
# Processing Record for yenagoa
# Processing Record for waconia
# Processing Record for abeche
# Processing Record for jizan
# Processing Record for mosjoen
# Processing Record for tamandare
# Processing Record for matiri
# Processing Record for khani
# Processing Record for sampit
# Processing Record for emerald
# Processing Record for itoman
# Processing Record for uchaly
# Processing Record for labrea
# Processing Record for chaozhou
# Processing Record for naze
# Processing Record for pitkyaranta
# Processing Record for eenhana
# Processing Record for yanan
# City not found. Skipping...
# Processing Record for mackay
# Processing Record for masuguru
# Processing Record for werda
# Processing Record for mineiros
# Processing Record for januaria
# Processing Record for chapais
# Processing Record for kitui
# Processing Record for riviere-au-renard
# Processing Record for turukhansk
# Processing Record for predejane
# Processing Record for babanusah
# City not found. Skipping...
# Processing Record for bathsheba
# Processing Record for palabuhanratu
# City not found. Skipping...
# Processing Record for novopskov
# Processing Record for tessalit
# Processing Record for sao miguel do araguaia
# Processing Record for sola
# Processing Record for granja
# Processing Record for monrovia
# Processing Record for tayginka
# Processing Record for aranos
# Processing Record for lysva
# Processing Record for broome
# Processing Record for wamba
# Processing Record for burica
# City not found. Skipping...
# Processing Record for faya
# Processing Record for bandar-e torkaman
# City not found. Skipping...
# Processing Record for mackenzie
# Processing Record for malakal
# Processing Record for armeria
# Processing Record for zyryanovsk
# Processing Record for cuamba
# Processing Record for talara
# Processing Record for lithakia
# Processing Record for waingapu
# Processing Record for sarkand
# Processing Record for neryungri
# Processing Record for vanderhoof
# Processing Record for santa eulalia del rio
# City not found. Skipping...
# Processing Record for narsaq
# Processing Record for uwayl
# City not found. Skipping...
# Processing Record for sumbawa
# City not found. Skipping...
# Processing Record for hofn
# Processing Record for jinchang
# Processing Record for kaspiyskiy
# Processing Record for kattivakkam
# Processing Record for goure
# Processing Record for thabazimbi
# Processing Record for pierre
# Processing Record for marzuq
# Processing Record for kodinsk
# Processing Record for takoradi
# Processing Record for miranda de ebro
# Processing Record for angra dos reis
# Processing Record for brigantine
# Processing Record for krasnoselkup
# Processing Record for shirvan
# Processing Record for san lorenzo
# Processing Record for alyangula
# Processing Record for arlit
# Processing Record for korla
# Processing Record for lusaka
# Processing Record for fort collins
# Processing Record for halalo
# City not found. Skipping...
# Processing Record for tabou
# Processing Record for baykit
# Processing Record for koumac
# Processing Record for gao
# Processing Record for keetmanshoop
# Processing Record for medvezhyegorsk
# Processing Record for loandjili
# Processing Record for utiroa
# City not found. Skipping...
# Processing Record for lillehammer
# Processing Record for negombo
# Processing Record for kailua
# Processing Record for tumannyy
# City not found. Skipping...
# Processing Record for ahualulco
# Processing Record for shirokiy
# Processing Record for baytown
# Processing Record for nantucket
# Processing Record for placerville
# Processing Record for maarianhamina
# Processing Record for aflu
# City not found. Skipping...
# Processing Record for greymouth
# Processing Record for pangkalanbuun
# Processing Record for eravur
# Processing Record for olafsvik
# Processing Record for cuenca
# Processing Record for dickinson
# Processing Record for tarnogskiy gorodok
# Processing Record for chicama
# Processing Record for joshimath
# Processing Record for puerto escondido
# Processing Record for bengkulu
# Processing Record for vostok
# Processing Record for wolgast
# Processing Record for taltal
# Processing Record for nivala
# Processing Record for udachnyy
# Processing Record for barguzin
# Processing Record for zaraza
# Processing Record for druzhba
# Processing Record for razole
# Processing Record for caravelas
# Processing Record for xifeng
# Processing Record for marystown
# Processing Record for obigarm
# Processing Record for poyarkovo
# Processing Record for sao joao da barra
# Processing Record for skeldon
# Processing Record for rungata
# City not found. Skipping...
# Processing Record for kingman
# Processing Record for hutchinson
# Processing Record for tosya
# Processing Record for mehran
# Processing Record for husainabad
# Processing Record for san-pedro
# Processing Record for dabola
# Processing Record for cameta
# Processing Record for dawson creek
# Processing Record for belmonte
# Processing Record for wheeling
# Processing Record for praia da vitoria
# Processing Record for shache
# Processing Record for constantine
# Processing Record for derzhavinsk
# Processing Record for beitbridge
# Processing Record for gangotri
# City not found. Skipping...
# Processing Record for balabac
# Processing Record for samalaeulu
# City not found. Skipping...
# Processing Record for sayaxche
# Processing Record for samana
# Processing Record for lagoa
# Processing Record for bandarbeyla
# Processing Record for wasilla
# Processing Record for sosnovo-ozerskoye
# Processing Record for xinqing
# Processing Record for nizhniy baskunchak
# Processing Record for mahuva
# Processing Record for vallenar
# Processing Record for rabo de peixe
# Processing Record for rio de janeiro
# Processing Record for thap than
# Processing Record for dongsheng
# Processing Record for dhemaji
# Processing Record for ambilobe
# Processing Record for sulangan
# Processing Record for penzance
# Processing Record for babaeski
# Processing Record for brownsville
# Processing Record for durazno
# Processing Record for santa cruz del norte
# Processing Record for tabat
# Processing Record for williamsburg
# Processing Record for karpinsk
# Processing Record for jawa
# Processing Record for dudinka
# Processing Record for shitanjing
# Processing Record for hopelchen
# Processing Record for chillicothe
# Processing Record for biltine
# Processing Record for raudeberg
# Processing Record for sechura
# Processing Record for westport
# Processing Record for resplendor
# Processing Record for la palma
# Processing Record for port blair
# Processing Record for ngukurr
# City not found. Skipping...
# Processing Record for la rioja
# Processing Record for cefalu
# Processing Record for winnemucca
# Processing Record for gusau
# Processing Record for erikoussa
# City not found. Skipping...
# Processing Record for maine-soroa
# Processing Record for mayo
# Processing Record for haldensleben
# Processing Record for sibolga
# Processing Record for velizh
# Processing Record for piracuruca
# Processing Record for abha
# Processing Record for lima
# Processing Record for jumla
# Processing Record for rivera
# Processing Record for suluq
# Processing Record for sabla
# Processing Record for kudahuvadhoo
# Processing Record for bodden town
# Processing Record for buchanan
# Processing Record for port-gentil
# Processing Record for gornopravdinsk
# Processing Record for khorramabad
# Processing Record for ulety
# Processing Record for kungurtug
# Processing Record for contadero
# Processing Record for rudbar
# Processing Record for puerto ayacucho
# Processing Record for mnogovershinnyy
# Processing Record for fenoarivo
# Processing Record for kuhestan
# City not found. Skipping...
# Processing Record for tefe
# Processing Record for kirensk
# Processing Record for yuryev-polskiy
# Processing Record for pemangkat
# Processing Record for punta alta
# Processing Record for vanimo
# Processing Record for beinamar
# Processing Record for neustadt
# Processing Record for kabalo
# Processing Record for elizabeth city
# Processing Record for azimur
# City not found. Skipping...
# Processing Record for baculin
# Processing Record for adrar
# Processing Record for diego de almagro
# Processing Record for verkhnyaya inta
# Processing Record for senj
# Processing Record for cockburn town
# Processing Record for yangjiang
# Processing Record for broken hill
# Processing Record for vogan
# Processing Record for hunza
# City not found. Skipping...
# Processing Record for sangar
# Processing Record for mocambique
# City not found. Skipping...
# Data Retrieval Complete

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Longyearbyen      SJ  78.2186   15.6401     -5.21        94          95
# 1        Khatanga      RU  71.9667  102.5000    -20.58        94          66
# 2    Punta Arenas      CL -53.1500  -70.9167     50.00        46          20
# 3           Tiksi      RU  71.6872  128.8694     -3.69        92          73
# 4  Severo-Kurilsk      RU  50.6789  156.1250     31.80        82          34
# 5         Itaguai      BR -22.8522  -43.7753     81.00        78          75
# 6            Kabo      CF   7.6994   18.6290     84.24        34          92
# 7          Lompoc      US  34.6391 -120.4579     55.40        67          90
# 8     New Norfolk      AU -42.7826  147.0587     53.01        54          20
# 9     Clyde River      CA  70.4692  -68.5914     -5.80        84          75
#
#    Wind Speed Current Description
# 0        4.61     overcast clouds
# 1       12.71       broken clouds
# 2       17.27          few clouds
# 3        8.16       broken clouds
# 4       13.96    scattered clouds
# 5        5.75       broken clouds
# 6        3.04     overcast clouds
# 7       13.80     overcast clouds
# 8        9.22          few clouds
# 9       24.16                snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
